# %%
from Bio.Seq import Seq
unknown_seq = Seq(None, 10)

# %%
unknown_seq
# Out:
# Seq(None, length=10)

# %%
len(unknown_seq)
# Out:
# 10

# %%
print(unknown_seq)
# Out:
# ---------------------------------------------------------------------------
# UndefinedSequenceError                    Traceback (most recent call last)
# /tmp/ipykernel_18244/167484.py in <cell line: 0>()
# ----> 1 print(unknown_seq)
#
# /usr/local/lib/python3.12/dist-packages/Bio/Seq.py in __str__(self)
#     405     def __str__(self):
#     406         """Return the full sequence as a python string."""
# --> 407         return self._data.decode("ASCII")
#     408
#     409     def __eq__(self, other):
#
# /usr/local/lib/python3.12/dist-packages/Bio/Seq.py in decode(self, encoding)
#     153           The encoding with which to decode the bytes.
#     154         """
# --> 155         return bytes(self).decode(encoding)
#     156
#     157     def count(self, sub, start=None, end=None):
#
# /usr/local/lib/python3.12/dist-packages/Bio/Seq.py in __bytes__(self)
#    2385
#    2386     def __bytes__(self):
# ...
